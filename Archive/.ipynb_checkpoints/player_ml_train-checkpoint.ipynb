# %%
# Code repurposed for testing from 
#https://www.kaggle.com/kazmiekr/predicting-nhl-hall-of-famers/comments

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNBS
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import imblearn
from imblearn.ensemble import BalancedRandomForestClassifier


# %matplotlib inline
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c511933e4632> in <module>
#       5 from sklearn.ensemble import RandomForestClassifier
#       6 from sklearn.neighbors import KNeighborsClassifier
# ----> 7 from sklearn.naive_bayes import GaussianNBS
#       8 from sklearn.linear_model import Perceptron
#       9 from sklearn.linear_model import SGDClassifier
#
# ImportError: cannot import name 'GaussianNBS'

# %%
master_df = pd.read_csv('Jeff/Output/test_train_file.csv')
master_df.head()
# Out:
#           Player    GP    G     A    TP    PPG   PIM  Years POS  firstYear  \
# 0  Wayne Gretzky  1487  894  1963  2857  1.921   577     20   C       1979
# 1   Mark Messier  1756  694  1193  1887  1.075  1910     25   C       1979
# 2    Gordie Howe  1767  801  1049  1850  1.047  1685     26  RW       1946
# 3    Ron Francis  1731  549  1249  1798  1.039   979     23   C       1981
# 4  Marcel Dionne  1348  731  1040  1771  1.314   600     18   C       1971
#
#    ...  Art Ross Awards  Conn Smythe Awards  Hart Awards  Calder Awards  \
# 0  ...               10                   2            9              0
# 1  ...                0                   1            2              0
# 2  ...                6                   0            6              0
# 3  ...                0                   0            0              0
# 4  ...                1                   0            0              0
#
#    James Norris Awards  Ted Lindsay Awards  Maurice Richard Awards  Cups  \
# 0                    0                   5                       0     4
# 1                    0                   2                       0     0
# 2                    0                   0                       0     4
# 3                    0                   0                       0     2
# 4                    0                   2                       0     0
#
#    All-Star Games  HoF
# 0              18    1
# 1              15    1
# 2              23    1
# 3               4    1
# 4               8    1
#
# [5 rows x 21 columns]

# %%
master_df.columns
# Out:
# Index(['Player', 'GP', 'G', 'A', 'TP', 'PPG', 'PIM', 'Years', 'POS',
#        'firstYear', 'lastYear', 'Art Ross Awards', 'Conn Smythe Awards',
#        'Hart Awards', 'Calder Awards', 'James Norris Awards',
#        'Ted Lindsay Awards', 'Maurice Richard Awards', 'Cups',
#        'All-Star Games', 'HoF'],
#       dtype='object')

# %%
new_hof = ['Jarome Iginla', 'Marian Hossa','Martin St. Louis','Teemu Selanne','Nicklas Lidstrom','Chris Pronger','Mark Recchi','Mike Modano','Peter Forsberg']
new_hof
# Out:
# ['Jarome Iginla',
#  'Marian Hossa',
#  'Martin St. Louis',
#  'Teemu Selanne',
#  'Nicklas Lidstrom',
#  'Chris Pronger',
#  'Mark Recchi',
#  'Mike Modano',
#  'Peter Forsberg']

# %%
#drop hof additions since 2011 for testing purposes
inverse_boolean_series = ~master_df.Player.isin(new_hof)
retired_players = master_df[inverse_boolean_series]

retired_players = retired_players[retired_players['GP']>=100]

#create df with only new hof additions for testing
boolean_series = master_df.Player.isin(new_hof)
new_hof_df = master_df[boolean_series]
# print(new_hof_df)


initial_eligible_players = pd.read_csv('Jeff/Output/predict_file.csv')

#isolate any 'active' hof in the eligible players dataset
active_hof = initial_eligible_players[initial_eligible_players['HoF'] == 1]
# print(active_hof)
#append any 'active' hof players to the test set
new_hof_df = new_hof_df.append(active_hof)

#update the eligible players df
eligible_players = initial_eligible_players[initial_eligible_players['HoF'] == 0]
# print(new_hof_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e6f1be7e9b6e> in <module>
#       1 #drop hof additions since 2011 for testing purposes
# ----> 2 inverse_boolean_series = ~master_df.Player.isin(new_hof)
#       3 retired_players = master_df[inverse_boolean_series]
#       4
#       5 retired_players = retired_players[retired_players['GP']>=100]
#
# NameError: name 'master_df' is not defined

# %%
cols_to_drop = ['Player','firstYear', 'lastYear','POS', 'HoF']

# %%
# print(new_hof_df)

# %%
#Training Set
train=retired_players.sample(frac=0.70, random_state=16)
# print(train.shape)

#Test Set
test=retired_players.drop(train.index)
# print(test.shape)

X_train = train.drop(cols_to_drop, axis=1)
Y_train = train['HoF']
X_test = test.drop(cols_to_drop, axis=1).copy()
Y_test = test['HoF']

# Dataset with unknown HoF predictions
X_player_test = eligible_players.drop(cols_to_drop, axis=1).copy()

# Create a test set of players that have made the HF since the last year of available data in this data set
# We'll just fill the Y with 1's
X_new_hof_test = new_hof_df.drop(cols_to_drop, axis=1).copy()
Y_new_hof_test = np.ones(X_new_hof_test.shape[0], dtype=np.int)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((4098, 16), (4098,), (1757, 16), (1757,))

# %%
classifiers = {}
# Run a classifier instance against the training set
def run_classifier(classifier):
    # Get the name of the classifier instance
    class_name = classifier.__class__.__name__
    print("Testing {0}".format(class_name))
    print("----------------------------------------\n")
    
    # Fit the classifier to the training set
    classifier.fit(X_train, Y_train)
    # Find out the training accuracy
    training_accuracy = round(classifier.score(X_train, Y_train) * 100, 2)
    print("Training Score: {0}".format(training_accuracy))
    
    # Use the trained data to predict the next HoF's
    Y_pred = classifier.predict(X_test)
    
    # How accurate was it against the known set of recent HoF's
    hof_accuracy = test_current_hf(classifier)
    
    # Cross validation scores
    f1_score = f1(Y_test, Y_pred)
    
    
    print("\n----- Predictions -----\n")
    # For all the classifiers except LinearSVC, we'll determine the probability in addition
    # to the prediction
    if class_name != 'LinearSVC':
        (positive_predictions, _) = show_prediction_with_probabilities(classifier, X_player_test)
    else:
        (positive_predictions, _) = show_prediction(classifier, X_player_test)
        
    # Store our results per classifier for later analysis    
    classifiers[class_name] = {
        'Training Accuracy': training_accuracy,
        'F1 Score': f1_score,
        'Current HoF Accuracy': hof_accuracy
    }
    return positive_predictions

# Given our set of known recent HoF additions, does the classifier think they should have made it?
def test_current_hf(classifier):
    accuracy = round(classifier.score(X_new_hof_test, Y_new_hof_test) * 100, 2)
    print("Accuracy with Current HF: {0}".format(accuracy))
    return accuracy

# Display from cross validation scores, F1, precision, recall
def f1(Y_test, Y_pred):
    macro = f1_score(Y_test.values, Y_pred, average='macro')
    print("F1 Score: {0}".format(formatPercent(macro)))
    precision = precision_score(Y_test.values, Y_pred, average='macro')
    print("Precision Score: {0}".format(formatPercent(precision)))
    recall = recall_score(Y_test.values, Y_pred, average='macro')
    print("Recall Score: {0}".format(formatPercent(recall)))
    return macro

def formatPercent(num):
    return round(num, 2)
    
def show_prediction_with_probabilities(classifier, X_player_test, display=True):
    prediction = classifier.predict(X_player_test)
    prob = classifier.predict_proba(X_player_test)
    pred_df = pd.DataFrame({
#         "playerID": eligible_players["playerID"],
        "Player": eligible_players["Player"],
        "isInHfPrediction": prediction,
        #"prob1": prob[:,0],
        "probability": prob[:,1]
    })
    positive_predictions = pred_df[pred_df['isInHfPrediction'] == 1]
    if display == True:
        print(positive_predictions.sort_values(by='probability', ascending=False))    
    return positive_predictions, pred_df

def show_prediction(classifier, X_player_test):
    prediction = classifier.predict(X_player_test)
    pred_df = pd.DataFrame({
#         "playerID": eligible_players["playerID"],
        "Player": eligible_players["Player"],
        "isInHfPrediction": prediction
    })
    positive_predictions = pred_df[pred_df['isInHfPrediction'] == 1]
    print(positive_predictions)
    return positive_predictions, pred_df

# %%
nn = MLPClassifier(alpha=1)
nn_pred = run_classifier(nn)
# Out:
# Testing MLPClassifier
# ----------------------------------------
#
# Training Score: 93.36
# Accuracy with Current HF: 100.0
# F1 Score: 0.67
# Precision Score: 0.62
# Recall Score: 0.82
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction  probability
# 0          Jaromir Jagr                 1     1.000000
# 3    Alexander Ovechkin                 1     1.000000
# 4         Sidney Crosby                 1     1.000000
# 1          Joe Thornton                 1     1.000000
# 7        Yevgeni Malkin                 1     1.000000
# 10         Patrick Kane                 1     0.999998
# 21       Steven Stamkos                 1     0.999992
# 45          Zdeno Chara                 1     0.999936
# 8          Henrik Sedin                 1     0.999821
# 13         Ryan Getzlaf                 1     0.999762
# 103      Connor McDavid                 1     0.999608
# 56        Erik Karlsson                 1     0.999351
# 76      Nikita Kucherov                 1     0.998126
# 78          Kris Letang                 1     0.997906
# 128         P.K. Subban                 1     0.996920
# 94         Dion Phaneuf                 1     0.995269
# 22        Claude Giroux                 1     0.995070
# 32         John Tavares                 1     0.994638
# 26          Corey Perry                 1     0.993790
# 39       Scott Hartnell                 1     0.992764
# 17    Nicklas Backstrom                 1     0.990748
# 18       Ilya Kovalchuk                 1     0.987966
# 82     Dustin Byfuglien                 1     0.981846
# 90         Drew Doughty                 1     0.975294
# 40          Marc Savard                 1     0.974273
# 228     Auston Matthews                 1     0.963084
# 24       Jonathan Toews                 1     0.958824
# 25            Rick Nash                 1     0.955005
# 110        Evander Kane                 1     0.943948
# 54         Duncan Keith                 1     0.918353
# 15         Anze Kopitar                 1     0.912415
# 64           Shea Weber                 1     0.902854
# 42          Brent Burns                 1     0.901448
# 49         Tyler Seguin                 1     0.900178
# 92     Nathan MacKinnon                 1     0.879435
# 62         Keith Yandle                 1     0.851708
# 113     Johnny Gaudreau                 1     0.844803
# 127      Leon Draisaitl                 1     0.831491
# 11           Eric Staal                 1     0.817774
# 70        Ryan O'Reilly                 1     0.802342
# 102       Victor Hedman                 1     0.790695
# 177         Jack Eichel                 1     0.780086
# 154      David Pastrnak                 1     0.766733
# 93       Wayne Simmonds                 1     0.696348
# 83          Milan Lucic                 1     0.689596
# 33        Blake Wheeler                 1     0.686233
# 318       Mathew Barzal                 1     0.654134
# 423            Ian Cole                 1     0.619074
# 73         David Backes                 1     0.611403
# 77           James Neal                 1     0.606404
# 147   Yevgeni Kuznetsov                 1     0.605902
# 124  Vladimir Tarasenko                 1     0.585910
# 68          Taylor Hall                 1     0.583127
# 108      Brent Seabrook                 1     0.564495
# 119    Brandon Dubinsky                 1     0.557747
# 329      David Clarkson                 1     0.534529
# 28         Mike Ribeiro                 1     0.534054
# 136          Roman Josi                 1     0.530600
# 66        Andrei Markov                 1     0.509217
# 341      Travis Hamonic                 1     0.508740

# %%
logreg = LogisticRegression()
logreg_pred = run_classifier(logreg)
# Out:
# Testing LogisticRegression
# ----------------------------------------
#
# Training Score: 97.97
# Accuracy with Current HF: 88.89
# F1 Score: 0.76
# Precision Score: 0.88
# Recall Score: 0.7
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction  probability
# 0          Jaromir Jagr                 1     0.999995
# 4         Sidney Crosby                 1     0.999441
# 7        Yevgeni Malkin                 1     0.995715
# 3    Alexander Ovechkin                 1     0.993643
# 10         Patrick Kane                 1     0.990551
# 1          Joe Thornton                 1     0.962460
# 40          Marc Savard                 1     0.821784
# 78          Kris Letang                 1     0.721446
# 23       Marian Gaborik                 1     0.695954
# 24       Jonathan Toews                 1     0.540266
# 21       Steven Stamkos                 1     0.535619
# 103      Connor McDavid                 1     0.514407
# C:\Users\Y243863\Anaconda3\envs\bcs\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
svc = SVC(probability=True)
svc_pred = run_classifier(svc)
# Out:
# Testing SVC
# ----------------------------------------
#
# Training Score: 97.46
# Accuracy with Current HF: 66.67
# F1 Score: 0.62
# Precision Score: 0.85
# Recall Score: 0.57
#
# ----- Predictions -----
#
#                Player  isInHfPrediction  probability
# 1        Joe Thornton                 1     0.995737
# 3  Alexander Ovechkin                 1     0.984105
# 4       Sidney Crosby                 1     0.972966
# 0        Jaromir Jagr                 1     0.950859
# 5     Patrick Marleau                 1     0.780307
# 8        Henrik Sedin                 1     0.670643
# 7      Yevgeni Malkin                 1     0.629395

# %%
coeff_df = pd.DataFrame(retired_players.columns.drop(['Player','firstYear', 'lastYear','POS', 'HoF']))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#                    Feature  Correlation
# 7          Art Ross Awards     1.080924
# 9              Hart Awards     0.770400
# 14                    Cups     0.626107
# 6                    Years     0.559009
# 11     James Norris Awards     0.520994
# 15          All-Star Games     0.338212
# 8       Conn Smythe Awards     0.199207
# 2                        A     0.193088
# 1                        G     0.192324
# 12      Ted Lindsay Awards     0.050171
# 5                      PIM    -0.000069
# 13  Maurice Richard Awards    -0.007425
# 10           Calder Awards    -0.008166
# 0                       GP    -0.009722
# 3                       TP    -0.186600
# 4                      PPG    -0.542969

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn_pred = run_classifier(knn)
# Out:
# Testing KNeighborsClassifier
# ----------------------------------------
#
# Training Score: 98.0
# Accuracy with Current HF: 77.78
# F1 Score: 0.62
# Precision Score: 0.72
# Recall Score: 0.58
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction  probability
# 0          Jaromir Jagr                 1     1.000000
# 3    Alexander Ovechkin                 1     1.000000
# 4         Sidney Crosby                 1     1.000000
# 5       Patrick Marleau                 1     1.000000
# 138   Aleksander Barkov                 1     1.000000
# 27      Justin Williams                 1     1.000000
# 1          Joe Thornton                 1     1.000000
# 76      Nikita Kucherov                 1     1.000000
# 124  Vladimir Tarasenko                 1     0.666667
# 228     Auston Matthews                 1     0.666667
# 201         J.T. Miller                 1     0.666667
# 166        Mike Hoffman                 1     0.666667
# 133        Sean Monahan                 1     0.666667
# 132      Artemi Panarin                 1     0.666667
# 129     Jay Bouwmeester                 1     0.666667
# 127      Leon Draisaitl                 1     0.666667
# 53         Chris Kunitz                 1     0.666667
# 113     Johnny Gaudreau                 1     0.666667
# 61          Mike Fisher                 1     0.666667
# 46         Dustin Brown                 1     0.666667
# 17    Nicklas Backstrom                 1     0.666667
# 16         Jason Spezza                 1     0.666667
# 14    Henrik Zetterberg                 1     0.666667
# 11           Eric Staal                 1     0.666667
# 10         Patrick Kane                 1     0.666667
# 8          Henrik Sedin                 1     0.666667
# 257       Brayden Point                 1     0.666667

# %%
gaussian = GaussianNB()
gaussian_pred = run_classifier(gaussian)
# Out:
# Testing GaussianNB
# ----------------------------------------
#
# Training Score: 96.34
# Accuracy with Current HF: 100.0
# F1 Score: 0.76
# Precision Score: 0.72
# Recall Score: 0.82
#
# ----- Predictions -----
#
#                Player  isInHfPrediction  probability
# 0        Jaromir Jagr                 1     1.000000
# 107      Jeff Skinner                 1     1.000000
# 45        Zdeno Chara                 1     1.000000
# 54       Duncan Keith                 1     1.000000
# 56      Erik Karlsson                 1     1.000000
# ..                ...               ...          ...
# 35        Matt Cullen                 1     0.999542
# 19   Patrice Bergeron                 1     0.999477
# 30       Joe Pavelski                 1     0.988061
# 53       Chris Kunitz                 1     0.986321
# 34        Jeff Carter                 1     0.960572
#
# [61 rows x 3 columns]

# %%
linear_svc = LinearSVC()
linear_svc_pred = run_classifier(linear_svc)
# Out:
# Testing LinearSVC
# ----------------------------------------
#
# Training Score: 95.31
# Accuracy with Current HF: 77.78
# F1 Score: 0.65
# Precision Score: 0.63
# Recall Score: 0.67
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction
# 0          Jaromir Jagr                 1
# 1          Joe Thornton                 1
# 3    Alexander Ovechkin                 1
# 4         Sidney Crosby                 1
# 5       Patrick Marleau                 1
# 7        Yevgeni Malkin                 1
# 9          Daniel Sedin                 1
# 10         Patrick Kane                 1
# 11           Eric Staal                 1
# 12           Shane Doan                 1
# 15         Anze Kopitar                 1
# 18       Ilya Kovalchuk                 1
# 19     Patrice Bergeron                 1
# 20          Phil Kessel                 1
# 21       Steven Stamkos                 1
# 23       Marian Gaborik                 1
# 24       Jonathan Toews                 1
# 25            Rick Nash                 1
# 26          Corey Perry                 1
# 27      Justin Williams                 1
# 29          Zach Parise                 1
# 30         Joe Pavelski                 1
# 31         Thomas Vanek                 1
# 32         John Tavares                 1
# 34          Jeff Carter                 1
# 39       Scott Hartnell                 1
# 43           Jamie Benn                 1
# 46         Dustin Brown                 1
# 47        Brad Marchand                 1
# 49         Tyler Seguin                 1
# 52        Patrick Sharp                 1
# 53         Chris Kunitz                 1
# 72       Max Pacioretty                 1
# 76      Nikita Kucherov                 1
# 77           James Neal                 1
# 79          Andrew Ladd                 1
# 93       Wayne Simmonds                 1
# 98     Patric Hornqvist                 1
# 107        Jeff Skinner                 1
# 110        Evander Kane                 1
# 124  Vladimir Tarasenko                 1
# C:\Users\Y243863\Anaconda3\envs\bcs\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree_pred = run_classifier(decision_tree)
# Out:
# Testing DecisionTreeClassifier
# ----------------------------------------
#
# Training Score: 100.0
# Accuracy with Current HF: 88.89
# F1 Score: 0.73
# Precision Score: 0.73
# Recall Score: 0.73
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction  probability
# 0          Jaromir Jagr                 1          1.0
# 1          Joe Thornton                 1          1.0
# 228     Auston Matthews                 1          1.0
# 165        Troy Brouwer                 1          1.0
# 128         P.K. Subban                 1          1.0
# 127      Leon Draisaitl                 1          1.0
# 112    Alex Pietrangelo                 1          1.0
# 103      Connor McDavid                 1          1.0
# 102       Victor Hedman                 1          1.0
# 76      Nikita Kucherov                 1          1.0
# 70        Ryan O'Reilly                 1          1.0
# 64           Shea Weber                 1          1.0
# 56        Erik Karlsson                 1          1.0
# 54         Duncan Keith                 1          1.0
# 49         Tyler Seguin                 1          1.0
# 43           Jamie Benn                 1          1.0
# 42          Brent Burns                 1          1.0
# 35          Matt Cullen                 1          1.0
# 32         John Tavares                 1          1.0
# 27      Justin Williams                 1          1.0
# 25            Rick Nash                 1          1.0
# 22        Claude Giroux                 1          1.0
# 21       Steven Stamkos                 1          1.0
# 11           Eric Staal                 1          1.0
# 10         Patrick Kane                 1          1.0
# 9          Daniel Sedin                 1          1.0
# 8          Henrik Sedin                 1          1.0
# 7        Yevgeni Malkin                 1          1.0
# 5       Patrick Marleau                 1          1.0
# 4         Sidney Crosby                 1          1.0
# 3    Alexander Ovechkin                 1          1.0
# 427  Oliver Bjorkstrand                 1          1.0

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest_pred = run_classifier(random_forest)
# Out:
# Testing RandomForestClassifier
# ----------------------------------------
#
# Training Score: 100.0
# Accuracy with Current HF: 100.0
# F1 Score: 0.79
# Precision Score: 0.87
# Recall Score: 0.74
#
# ----- Predictions -----
#
#                  Player  isInHfPrediction  probability
# 0          Jaromir Jagr                 1         1.00
# 3    Alexander Ovechkin                 1         0.97
# 1          Joe Thornton                 1         0.94
# 10         Patrick Kane                 1         0.93
# 4         Sidney Crosby                 1         0.86
# 76      Nikita Kucherov                 1         0.86
# 103      Connor McDavid                 1         0.84
# 127      Leon Draisaitl                 1         0.82
# 7        Yevgeni Malkin                 1         0.82
# 43           Jamie Benn                 1         0.76
# 8          Henrik Sedin                 1         0.75
# 5       Patrick Marleau                 1         0.67
# 54         Duncan Keith                 1         0.66
# 26          Corey Perry                 1         0.65
# 21       Steven Stamkos                 1         0.64
# 68          Taylor Hall                 1         0.63
# 56        Erik Karlsson                 1         0.61
# 11           Eric Staal                 1         0.60
# 27      Justin Williams                 1         0.60
# 9          Daniel Sedin                 1         0.59
# 45          Zdeno Chara                 1         0.51

# %%
model_performance = pd.DataFrame.from_dict(classifiers, orient='index')
model_performance.sort_values(by='F1 Score', ascending=False)
# Out:
#                         Training Accuracy  F1 Score  Current HoF Accuracy
# RandomForestClassifier             100.00  0.793744                100.00
# GaussianNB                          96.34  0.758160                100.00
# LogisticRegression                  97.97  0.756967                 88.89
# DecisionTreeClassifier             100.00  0.730028                 88.89
# MLPClassifier                       93.36  0.670391                100.00
# LinearSVC                           95.31  0.650363                 77.78
# SVC                                 97.46  0.618043                 66.67
# KNeighborsClassifier                98.00  0.617156                 77.78

# %%
gaussian_pred.sort_values(by='probability', ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03ff908b0b02> in <module>
# ----> 1 gaussian_pred.sort_values(by='probability', ascending=False).head(20)
#
# NameError: name 'gaussian_pred' is not defined
